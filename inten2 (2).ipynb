# %%
import pandas as pd

df = pd.read_csv('titanic_cleaned.csv')  
print(df.head())       
print(df.info())        
print(df.describe())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name       Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris -0.528321      1      0
# 1                        Heikkinen, Miss. Laina -0.215182      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.489381      1      0
# 3                      Allen, Mr. William Henry  0.489381      0      0
# 4                              Moran, Mr. James -0.058613      0      0
#
#              Ticket      Fare  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171 -0.779117      True       False        True
# 1  STON/O2. 3101282 -0.729373     False       False        True
# 2            113803  2.599828     False       False        True
# 3            373450 -0.720161      True       False        True
# 4            330877 -0.690071      True        True       False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  750 non-null    int64
#  1   Survived     750 non-null    int64
#  2   Pclass       750 non-null    int64
#  3   Name         750 non-null    object
#  4   Age          750 non-null    float64
#  5   SibSp        750 non-null    int64
#  6   Parch        750 non-null    int64
#  7   Ticket       750 non-null    object
#  8   Fare         750 non-null    float64
#  9   Sex_male     750 non-null    bool
#  10  Embarked_Q   750 non-null    bool
#  11  Embarked_S   750 non-null    bool
# dtypes: bool(3), float64(2), int64(5), object(2)
# memory usage: 55.1+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   750.000000  750.000000  750.000000  750.000000  750.000000
# mean    445.746667    0.325333    2.508000   -0.015165    0.438667
# std     260.420103    0.468812    0.711766    0.997730    0.910317
# min       1.000000    0.000000    1.000000   -2.217707    0.000000
# 25%     214.250000    0.000000    2.000000   -0.528321    0.000000
# 50%     449.500000    0.000000    3.000000   -0.058613    0.000000
# 75%     670.750000    1.000000    3.000000    0.411096    1.000000
# max     891.000000    1.000000    3.000000    4.012196    5.000000
#
#             Parch        Fare
# count  750.000000  750.000000
# mean     0.337333   -0.099073
# std      0.790172    0.853486
# min      0.000000   -1.313411
# 25%      0.000000   -0.731524
# 50%      0.000000   -0.408336
# 75%      0.000000    0.590931
# max      6.000000    2.599828

# %%
print("Missing values before processing:")
print(df.isnull().sum())


if 'Age' in df.columns:
    df['Age'] = df['Age'].fillna(df['Age'].mean())


if 'Cabin' in df.columns:
    df.drop(columns=['Cabin'], inplace=True)


print("\nMissing values after processing:")
print(df.isnull().sum())
# Out:
# Missing values before processing:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_male       0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64
#
# Missing values after processing:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_male       0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Distribution of Age")
plt.show()

sns.boxplot(x=df['Fare'])
plt.title("Boxplot of Fare")
plt.show()

# %%
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived']])
plt.show()

# Correlation
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe()

print("Median:\n", df.median(numeric_only=True))
print("Standard Deviation:\n", df.std(numeric_only=True))
# Out:
# Median:
#  PassengerId    449.500000
# Survived         0.000000
# Pclass           3.000000
# Age             -0.058613
# SibSp            0.000000
# Parch            0.000000
# Fare            -0.408336
# Sex_male         1.000000
# Embarked_Q       0.000000
# Embarked_S       1.000000
# dtype: float64
# Standard Deviation:
#  PassengerId    260.420103
# Survived         0.468812
# Pclass           0.711766
# Age              0.997730
# SibSp            0.910317
# Parch            0.790172
# Fare             0.853486
# Sex_male         0.463619
# Embarked_Q       0.300200
# Embarked_S       0.428981
# dtype: float64
